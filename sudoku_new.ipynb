# %%
from random import randint, sample, shuffle, random
from math import sqrt
import time
from __future__ import print_function
import copy
from numpy.random import choice
import operator

class SudokuSolver(object):
    def __init__(self, sudoku_size, init_values):
        self.sudoku_size = sudoku_size
        self.init_values = list(init_values)[:]
        self.fixed_positions = []
        self.free_positions = []
        self.population = []
        self.fitness_hash = {}
        self.available_numbers = {}

        for i in range(0, len(self.init_values)):
            if not(self.init_values[i] == str(0) or self.init_values[i] == '.'):
                self.init_values[i] = int(self.init_values[i])
                self.fixed_positions.append(i)
            else:
                self.free_positions.append(i)
                self.init_values[i] = 0
                
        for pos in self.free_positions:
            available_colors = set(range(1,10))
            for i in self.adyacent_indexes(pos):
                if self.init_values[i] in available_colors:
                    available_colors.remove(self.init_values[i])
            self.available_numbers[pos] = available_colors

        #self.printGrid(self.init_values)

    def nodes(self):
        return self.sudoku_size * self.sudoku_size

    def kcolors(self):
        return self.sudoku_size

    def edges(self):
        return (self.nodes() * (self.kcolors()-1 + (self.kcolors()-(sqrt(self.kcolors()))) * 2)) / 2

    def population(self):
        return self.population

    def printGrid(self, solution, printfile=None):
        for i in range(0, 9):
            if printfile is not None:
                print(solution[i*9:i*9+9], file=printfile)
            else:
                print(solution[i*9:i*9+9])

    def row_indexes(self, position):
        return range(int(position/self.sudoku_size)*9,int(position/self.sudoku_size)*9+9)

    def row_index(self, position):
        return int(position/self.sudoku_size)

    def col_index(self, position):
        return position%self.sudoku_size

    def col_indexes(self, position):
        return range(position%self.sudoku_size,73+(position%self.sudoku_size),9)

    def zone_number(self, position):
        row_index = self.row_index(position)
        col_index = self.col_index(position)
        if (row_index % 9 < 3):
            if (col_index % 9 < 3):
                return 0
            elif (col_index % 9 < 6):
                return 1
            else:
                return 2
        elif (row_index % 9 < 6):
            if (col_index % 9 < 3):
                return 3
            elif (col_index % 9 < 6):
                return 4
            else:
                return 5
        else:
            if (col_index % 9 < 3):
                return 6
            elif (col_index % 9 < 6):
                return 7
            else:
                return 8

    def zone_indexes(self, zone_number):
        first = self.sudoku_size * int(zone_number/3)*3 + zone_number % 3 * 3
        indexes = []
        for i in range(0, 3):
            indexes.append(first) 
            indexes.append(1 + first)
            indexes.append(2 + first)
            first = first + self.sudoku_size
        return indexes

    def zone_indexes_by_pos(self, position):
        zone_number = self.zone_number(position)
        return self.zone_indexes(zone_number)

    def adyacent_indexes(self, position):
        indexes = set()
        [indexes.add(x) for x in self.col_indexes(position)]
        [indexes.add(x) for x in self.row_indexes(position)]
        [indexes.add(x) for x in self.zone_indexes_by_pos(position)]
        indexes.remove(position)
        return indexes

    def reorderPopulation(self):
        new_fitness_hash = {}
        for solution in self.population:
            if self.sol2string(solution) in self.fitness_hash:
                new_fitness_hash[self.sol2string(solution)] = self.fitness_hash[self.sol2string(solution)]
            else:
                bad_edges = 0
                for pos in self.free_positions:
                    for ady in self.adyacent_indexes(pos):
                        if (solution[ady] == solution[pos]):
                            bad_edges += 1
                new_fitness_hash[self.sol2string(solution)] = bad_edges / 2

        # Envejezco al mejor
        if len(self.fitness_hash) > 0:
            best_old = max(self.fitness_hash.items(), key=operator.itemgetter(1))[0]
            best_new = max(new_fitness_hash.items(), key=operator.itemgetter(1))[0]
            if best_old == best_new:
                new_fitness_hash[self.sol2string(best_old)] += 1

        self.fitness_hash = new_fitness_hash
        self.population = sorted(self.population, key=self.fitness)

    def fitness(self, solution):
        return int(self.fitness_hash[self.sol2string(solution)])

    def sol2string(self, sol):
        s = ''
        for i in sol:
            s += str(i)
        return s

    def initPopulation(self, n_population):
        self.population = []
        for i in range(0, n_population):
            solution = self.createRandomSol()
            self.population.append(copy.copy(solution))

    def createRandomSol(self):
        solution = self.init_values
        indexes = copy.copy(self.free_positions)
        shuffle(indexes)
        while (len(indexes) > 0):
            i = indexes.pop()
            solution[i] = self.getAvailableNumber(i)
        return solution
    
    def getAvailableNumber(self, pos):
        return sample(self.available_numbers[pos], 1)[0]

    def select_parents(self, tournament_size = 5):
        n_population = len(self.population)

        participants = []
        for i in range(0, tournament_size):
            new = randint(0, int(n_population/2)-1)
            while new in participants:
                new = randint(0, int(n_population/2)-1)
            participants.append(new)

        participants = sorted(participants)
        parent1_index = participants[0]
        parent2_index = participants[1]
        
        return self.population[parent1_index], self.population[parent2_index]

    def crossover(self, parent1, parent2):
        # Por zonas
        solution = [0] * 81
        for zone_number in range(0,9):
            r = randint(0,1)
            if (r):
                parent = parent1
            else:
                parent = parent2
            indexes = self.zone_indexes(zone_number)
            for i in indexes:
                solution[i] = parent[i]
        return solution

    def mutation(self, solution, normal_proba=0.1, bad_colored_proba=0.9):
        indexes = copy.copy(self.free_positions)
        shuffle(indexes)
        while (len(indexes) > 0):
            i = indexes.pop()
            r = random()

            bad_colored = False

            for ady in self.adyacent_indexes(i):
                if solution[i] == solution[ady]:
                    bad_colored = True
                    break

            if bad_colored and r <= bad_colored_proba:
                solution[i] = self.getAvailableNumber(i)

            elif r <= normal_proba:
                solution[i] = self.getAvailableNumber(i)

        return solution

    def solve(self,
              n_population = 200,
              reset_point = 300,
              max_iters = 50000,
              crossover_proba = 0.9,
              selection_tournament_size = 5,
              normal_mutation_proba = 0.1,
              bad_colored_mutation_proba = 0.9,
              elitism_ratio = 0.5
             ):
        
        # Inicializacion de variables
        start_time = time.time()
        self.initPopulation(n_population)
        best_fitness = self.edges()
        iter_count = 0
        iter_without_improvement = 0
        elite_size = int(n_population * elitism_ratio)

        while (best_fitness > 0 and iter_count < max_iters):

            # Actualizacion del best fitness
            self.reorderPopulation()
            new_best = self.fitness(self.population[0])

            if (new_best < best_fitness):
                best_fitness = new_best
                iter_without_improvement = 0
                #print("iteration %d, new best_fitness %d" %(iter_count, best_fitness))
                #self.printGrid(self.population[0])
                if best_fitness == 0: 
                    break
            else:
                iter_without_improvement += 1

            # Restarts, para destrabar y resetear el algoritmo
            if iter_without_improvement > reset_point:
                print("Restarteando")
                self.initPopulation(n_population)
                best_fitness = self.edges()
                iter_without_improvement = 0

            else:
                # Actualizacion de la poblacion
                new_population = []
                for i in range(0, elite_size):
                    new_population.append(self.population[i])
                
                start_new_popu = time.time()

                for i in range(elite_size, n_population):
                    # Generacion del hijo, evito que se generen repetidos
                    hijo_repetido = True
                    intentos = 0
                    while (hijo_repetido):

                        # Seleccion de padres (tournament selection)
                        parent1, parent2 = self.select_parents(tournament_size=selection_tournament_size)

                        # Crossover

                        if random() <= crossover_proba:
                            child = self.crossover(parent1, parent2)
                        else:
                            child = copy.copy(parent1)

                        # Mutaciones
                        child = self.mutation(child,
                                              normal_proba = normal_mutation_proba,
                                              bad_colored_proba = bad_colored_mutation_proba)

                        # Chequeo si es repetido
                        hijo_repetido = False
                        for p in self.population :  
                            if p == child :
                                hijo_repetido = True
                                intentos += 1
                                break

                        # Si pasa el nro max de intentos repetidos genero un hijo random        
                        if intentos > 3 :
                            print("Creando Random")
                            child = self.createRandomSol()
                            hijo_repetido = False

                        if not(hijo_repetido):
                            new_population.append(copy.copy(child))

                #print("Tiempo new popu %s segundos" % (time.time() - start_new_popu))
                self.population = new_population

            iter_count = iter_count + 1

        # Resultado
        if (best_fitness == 0):
            print("--- Se resolvió el SUDOKU en %s segundos y %d iteraciones !!!! ---" % (time.time() - start_time, iter_count))
            #self.printGrid(self.population[0])
            return True, iter_count, time.time() - start_time
        else:
            print("NO ANDUVO, se obtuvo un fitness de %d luego de %s segundos y %d iteraciones :(" % (best_fitness, (time.time() - start_time), iter_count))
            return False, 0, time.time() - start_time

# %%
def test_sudoku_results(grid):
    s = SudokuSolver(9, grid)
    
    solved_count = 0
    solved_iters = []
    times = []

    for i in range(0, 100):
        solved, iters, time_elapsed = s.solve()
        if solved:
            solved_count += 1
            solved_iters.append(iters)
            times.append(time_elapsed)
    
    return solved_count, solved_iters, times

# %%
# Set de testeo para comparar con los papers
stars1 = '040000179002008054006005008080070910050090030019060040300400700570100200928000060'
stars2 = '206000049037009000100700006000580900705000804009062000900004001000300490410000208'
stars3 = '050200000300005080960078200000030020708000103040080000001640032070500001000009050'
stars4 = '050090000004800009000107280560000137000000000173000042021508000600003800000010060'
stars5 = '105000370000000200097300010000053102300801004201470000070008640008000000012000807'
easy = '008060900000203678706051004973048100620039050001700000580900306000000000040005721'
challenging = '002004000008600000090000030800062000140030509070000000035008607000000042000901003'
difficult = '670008010020060000000030000201000006480001700000000009004500000000000300003400802'
sdifficult = '090384000002070000000000071500003240030000000001005090000800000706520000000006400'

# %%
import numpy as np

def mostrarMedidas(count, iters, times):
    print("Count \t %d" % count)
    print("Min \t %d" % min(iters))
    print("Max \t %d" % max(iters))   
    print("Med \t %d" % np.median(iters))            
    print("Avg \t %f" % np.mean(iters))        
    print("Std \t %f" % np.std(iters))
    print("Time \t %f" % np.mean(times))

# %%
count1, iters1, times1 = test_sudoku_results(stars1)
mostrarMedidas(count1, iters1, times1)
# Out:
# --- Se resolvió el SUDOKU en 3.90260314941 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.08791780472 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.70534515381 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.2951939106 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.47411799431 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.65733790398 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.36898684502 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.33577179909 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.2915968895 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.44368100166 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.05939888954 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.75098490715 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.58781695366 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.57951712608 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.289539814 segundos y 25 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.79646921158 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.27570796013 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.55458188057 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.78153181076 segundos y 24 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.36187505722 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.5657980442 segundos y 26 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.46014881134 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.15723705292 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.38283610344 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.11890506744 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.17242693901 segundos y 29 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.97628211975 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.506731987 segundos y 23 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.45060610771 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.39909791946 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.2505710125 segundos y 23 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.04124307632 segundos y 17 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.21813702583 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.63739991188 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.52957510948 segundos y 23 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.37900805473 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.67673397064 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.1569108963 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.78737092018 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.78853392601 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.3479039669 segundos y 15 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.30001497269 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.6795091629 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.38630104065 segundos y 17 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.03233599663 segundos y 17 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.46330213547 segundos y 17 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.74466705322 segundos y 26 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.32203912735 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.04779410362 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.06887483597 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.71205401421 segundos y 24 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.16533589363 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.90168213844 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.45646286011 segundos y 25 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.45262789726 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.73176908493 segundos y 23 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.97010397911 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.74281215668 segundos y 27 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.98734402657 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.22431111336 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.22853088379 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.65064311028 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.06304812431 segundos y 15 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.07862997055 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.92490696907 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.64845204353 segundos y 23 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.53795480728 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.60420918465 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.74102401733 segundos y 24 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.55632805824 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.78680109978 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.00518202782 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.95109987259 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.25376105309 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.32024002075 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.94718003273 segundos y 20 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.50689387321 segundos y 15 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.68017911911 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.4330329895 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.25641202927 segundos y 23 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.33922719955 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.45676898956 segundos y 28 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.95681095123 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.84941720963 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.082695961 segundos y 17 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.96830511093 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.50254106522 segundos y 17 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.36679911613 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.70056080818 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.27363586426 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.80566000938 segundos y 25 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.98127198219 segundos y 21 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.66258311272 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.46916103363 segundos y 29 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.11470198631 segundos y 19 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 5.30026006699 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.18331003189 segundos y 18 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 6.20703887939 segundos y 26 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.94594407082 segundos y 22 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.74989104271 segundos y 21 iteraciones !!!! ---
# Count 	 100
# Min 	 12
# Max 	 29
# Med 	 20
# Avg 	 19.890000
# Std 	 3.599708
# Time 	 4.741091

# %%
count2, iters2, times2 = test_sudoku_results(stars2)
mostrarMedidas(count2, iters2, times2)

# %%
count3, iters3, times3 = test_sudoku_results(stars3)
mostrarMedidas(count3, iters3, times3)

# %%
count4, iters4, times4 = test_sudoku_results(stars4)
mostrarMedidas(count4, iters4, times4)

# %%
count5, iters5, times5 = test_sudoku_results(stars5)
mostrarMedidas(count5, iters5, times5)

# %%
counte, iterse, timese = test_sudoku_results(easy)
mostrarMedidas(counte, iterse, timese)
# Out:
# --- Se resolvió el SUDOKU en 2.38646197319 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.76511311531 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.83873486519 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.37618899345 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.08451700211 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.84988117218 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.63499498367 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.827917099 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.98352503777 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.07909297943 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.35358405113 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.79387807846 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.57827711105 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.12349700928 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.38006496429 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.36056494713 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.08214998245 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.79129219055 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.97256398201 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.52793192863 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.36382508278 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.1789419651 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.14939188957 segundos y 5 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.56921887398 segundos y 17 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.3500790596 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.78995704651 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.58752608299 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.68434095383 segundos y 7 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.1510720253 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.02968096733 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.87468791008 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.2409889698 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.36436009407 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.81372785568 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.1998000145 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.64193701744 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.91556501389 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.85480499268 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.67859506607 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.84666180611 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.54440784454 segundos y 6 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.10823178291 segundos y 15 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.38249397278 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.71355509758 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.4147541523 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.50187492371 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.16361689568 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.82522797585 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.74518203735 segundos y 6 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.54079699516 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.52867913246 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.24329304695 segundos y 7 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.13060998917 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.15473794937 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.56069803238 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.81202197075 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.61345601082 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.04849410057 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.11461496353 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.81090688705 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.31587696075 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.67495298386 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.30977606773 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.53160595894 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.85427999496 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.96123313904 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.86986780167 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.71794891357 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.46725988388 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.98565006256 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.53707885742 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.74157595634 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.13686609268 segundos y 16 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.21549105644 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.86735391617 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.39912509918 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.71686005592 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.72678303719 segundos y 8 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.36638712883 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.64709401131 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.50538921356 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.7214641571 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.92277312279 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.05447888374 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.97203707695 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.65840101242 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.69240283966 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.44219303131 segundos y 14 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.31450510025 segundos y 5 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.30521798134 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.20222616196 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 4.11459207535 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.64384317398 segundos y 9 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.83407616615 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.59897685051 segundos y 13 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.37082719803 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 1.97617197037 segundos y 11 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.39493298531 segundos y 12 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 2.81520700455 segundos y 10 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 3.19110679626 segundos y 10 iteraciones !!!! ---
# Count 	 100
# Min 	 5
# Max 	 17
# Med 	 11
# Avg 	 10.680000
# Std 	 2.288580
# Time 	 2.588324

# %%
countc, itersc, timesc = test_sudoku_results(challenging)
mostrarMedidas(countc, itersc, timesc)
# Out:
# --- Se resolvió el SUDOKU en 76.6203410625 segundos y 314 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 52.8347821236 segundos y 220 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 96.0204479694 segundos y 387 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 251.699048042 segundos y 1039 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 52.7551620007 segundos y 213 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 68.4363689423 segundos y 277 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 115.350200891 segundos y 486 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 73.4662292004 segundos y 298 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 81.0048451424 segundos y 325 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 95.4023308754 segundos y 405 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 107.27257514 segundos y 439 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 110.485905886 segundos y 454 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 62.5176310539 segundos y 257 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 150.980971813 segundos y 628 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 74.7122879028 segundos y 311 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 78.7424509525 segundos y 313 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 68.8644311428 segundos y 294 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 81.6244859695 segundos y 341 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 106.848555088 segundos y 445 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 57.3298091888 segundos y 230 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 72.7123761177 segundos y 297 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 83.4567360878 segundos y 349 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 125.079382181 segundos y 525 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 102.100242853 segundos y 428 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 92.095510006 segundos y 390 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 109.986829996 segundos y 451 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 106.492416859 segundos y 454 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 118.900882006 segundos y 514 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 92.642084837 segundos y 378 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 274.590393066 segundos y 1163 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 308.588654995 segundos y 1305 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 92.1153249741 segundos y 376 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 81.8720109463 segundos y 340 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 171.802232027 segundos y 741 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 73.7939891815 segundos y 305 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 85.1951270103 segundos y 357 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 60.8626680374 segundos y 253 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 111.832715034 segundos y 464 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 51.3636012077 segundos y 223 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 234.635357857 segundos y 971 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 341.582882881 segundos y 1452 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 93.942595005 segundos y 406 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 146.280947924 segundos y 623 iteraciones !!!! ---
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 437.471689939 segundos y 1855 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 59.7292611599 segundos y 248 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 137.117547035 segundos y 589 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 61.4178609848 segundos y 255 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 91.3750069141 segundos y 388 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 79.2920150757 segundos y 327 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 104.783761978 segundos y 446 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 47.1347339153 segundos y 190 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 71.4475269318 segundos y 298 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 65.1751170158 segundos y 277 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 70.5582199097 segundos y 294 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 131.279784918 segundos y 564 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 94.930464983 segundos y 395 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 56.0239479542 segundos y 231 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 57.7683570385 segundos y 240 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 160.007851124 segundos y 678 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 287.572007179 segundos y 1213 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 166.246870995 segundos y 694 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 84.4567780495 segundos y 354 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 107.833251953 segundos y 456 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 82.8746809959 segundos y 347 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 58.8128120899 segundos y 241 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 151.126966953 segundos y 632 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 49.1820399761 segundos y 204 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 85.2280158997 segundos y 358 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 72.6056859493 segundos y 312 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 92.2142729759 segundos y 381 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 99.4153289795 segundos y 429 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 78.0924870968 segundos y 323 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 99.3135280609 segundos y 413 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 112.057031155 segundos y 487 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 108.534755945 segundos y 459 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 72.4323611259 segundos y 301 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 67.649392128 segundos y 284 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 312.192281008 segundos y 1328 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 278.092576981 segundos y 1191 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 83.4342780113 segundos y 355 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 123.741483927 segundos y 495 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 331.261575937 segundos y 1288 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 72.1311230659 segundos y 282 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 63.0640990734 segundos y 267 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 86.432477951 segundos y 326 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 80.6837649345 segundos y 260 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 88.002243042 segundos y 327 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 652.261564016 segundos y 2438 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 99.0972559452 segundos y 373 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 51.198841095 segundos y 201 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 236.866326094 segundos y 907 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 87.4982361794 segundos y 343 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 73.6782832146 segundos y 278 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 88.6695520878 segundos y 347 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 82.2091648579 segundos y 318 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 99.3882789612 segundos y 384 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 98.8620078564 segundos y 379 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 104.970099926 segundos y 400 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 50.0677990913 segundos y 188 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 121.083989143 segundos y 476 iteraciones !!!! ---
# Count 	 100
# Min 	 188
# Max 	 2438
# Med 	 374
# Avg 	 487.550000
# Std 	 364.147014
# Time 	 118.609656

# %%
countd, itersd, timesd = test_sudoku_results(difficult)
mostrarMedidas(countd, itersd, timesd)
# Out:
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 1514.03490186 segundos y 5610 iteraciones !!!! ---
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 764.016508818 segundos y 3178 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 2094.40704203 segundos y 9290 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 2179.54015017 segundos y 9920 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 978.353760004 segundos y 4498 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 5708.78386283 segundos y 26584 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 2087.1204958 segundos y 9768 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 2138.38794208 segundos y 9987 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 2012.22293997 segundos y 9251 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 253.732106924 segundos y 1141 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 10135.2900941 segundos y 45480 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 975.66345787 segundos y 4430 iteraciones !!!! ---
# --- Se resolvió el SUDOKU en 330.743385077 segundos y 1528 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 877.613718987 segundos y 3994 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 1144.76821804 segundos y 5165 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 1306.85098219 segundos y 5762 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 420.244488001 segundos y 1783 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 1455.68189812 segundos y 6152 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 2192.225878 segundos y 8936 iteraciones !!!! ---
# Restarteando
# --- Se resolvió el SUDOKU en 321.447329044 segundos y 1284 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 2442.83104992 segundos y 9287 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 1404.83858991 segundos y 4179 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 10558.000706 segundos y 36456 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 1679.18803883 segundos y 6222 iteraciones !!!! ---
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 1049.03459692 segundos y 3794 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# --- Se resolvió el SUDOKU en 4355.02845502 segundos y 15996 iteraciones !!!! ---
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# Restarteando
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-402-c003ccc5f3a2> in <module>()
# ----> 1 countd, itersd, timesd = test_sudoku_results(difficult)
#       2 mostrarMedidas(countd, itersd, timesd)
#
# <ipython-input-398-8f7e35e22260> in test_sudoku_results(grid)
#       7
#       8     for i in range(0, 100):
# ----> 9         solved, iters, time_elapsed = s.solve()
#      10         if solved:
#      11             solved_count += 1
#
# <ipython-input-376-e9cecdebe94a> in solve(self, n_population, reset_point, max_iters, crossover_proba, selection_tournament_size, normal_mutation_proba, bad_colored_mutation_proba, elitism_ratio)
#     235
#     236             # Actualizacion del best fitness
# --> 237             self.reorderPopulation()
#     238             new_best = self.fitness(self.population[0])
#     239
#
# <ipython-input-376-e9cecdebe94a> in reorderPopulation(self)
#     119                 bad_edges = 0
#     120                 for pos in self.free_positions:
# --> 121                     for ady in self.adyacent_indexes(pos):
#     122                         if (solution[ady] == solution[pos]):
#     123                             bad_edges += 1
#
# <ipython-input-376-e9cecdebe94a> in adyacent_indexes(self, position)
#     107         [indexes.add(x) for x in self.col_indexes(position)]
#     108         [indexes.add(x) for x in self.row_indexes(position)]
# --> 109         [indexes.add(x) for x in self.zone_indexes_by_pos(position)]
#     110         indexes.remove(position)
#     111         return indexes
#
# <ipython-input-376-e9cecdebe94a> in zone_indexes_by_pos(self, position)
#     101     def zone_indexes_by_pos(self, position):
#     102         zone_number = self.zone_number(position)
# --> 103         return self.zone_indexes(zone_number)
#     104
#     105     def adyacent_indexes(self, position):
#
# <ipython-input-376-e9cecdebe94a> in zone_indexes(self, zone_number)
#      96             indexes.append(1 + first)
#      97             indexes.append(2 + first)
# ---> 98             first = first + self.sudoku_size
#      99         return indexes
#     100
#
# KeyboardInterrupt:

# %%
countsd, iterssd, timessd = test_sudoku_results(sdifficult)
mostrarMedidas(countsd, iterssd, timessd)
