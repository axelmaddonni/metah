tiempos11 = [254.077,242.516,310.496,61.3709,88.3705,1.34705,242.009,1.94327,65.8475,358.64,102.611,36.4009,36.1455,2.34099,80.6195,233.448,49.0311,20.1833,204.954,21.0093,3.48515,30.374,83.3675,205.295,1.82743,117.02,33.8832,48.7595,149.268]
tiempos12 = [111.894,44.6047,223.497,253.086,41.3463,259.125,245.675,51.3229]
tiempos13 = [0.945798,15.6983,0.999605,3.76468,1.43999,4.21333,1.13835,3.20203,1.67359,3.66187,9.1213,9.74084,6.31136,25.526,6.12894,24.6794,4.38258,6.21209,7.44043,2.58815,0.806337,0.871639,13.5843,1.89217,2.97516,1.38127,1.09147,3.41809,6.66917,8.16184]
tiempos14 = [9.4385,1.35155,196.312,120.298,44.8699,54.8171,41.201,193.834,2.06568,107.924,70.1666,4.20409,4.29235,136.165,125.892,200.75,60.922,2.03447,350.195,162.567,94.5222,7.91419,143.184,228.07,3.79781,95.9362,240.607,89.6758,72.0306]
tiempos15 = [18.5131,19.9416,43.6132,18.8762,111.457,43.5851,95.0067,150.6,8.49695,134.863,8.87621,84.6132,21.485,127.069,14.4293,40.2576,36.4006,66.763,206.753,35.5858,54.0278,45.3518,185.415,47.1066,239.082,4.06429,68.547,47.7289,111.258,111.39]

# %%
tiempos = [tiempos1, tiempos2, tiempos3, tiempos4, tiempos5, tiempos6, tiempos7, tiempos8, tiempos9, tiempos10, tiempos11, tiempos12, tiempos13, tiempos14, tiempos15]
iters = [iters1, iters2, iters3, iters4, iters5, iters6, iters7, iters8, iters9]

# %%
for i in range(0, 9):
    new_tiempos = []
    new_iters = []
    for j in range(0, len(tiempos[i])):
        if (tiempos[i][j] <= 180):
            new_tiempos.append(tiempos[i][j])
            new_iters.append(iters[i][j])
    tiempos[i] = new_tiempos
    iters[i] = new_iters

# %%
print("RESULTADOS EN SEGUNDOS")
for dificultad in range(1, 10):
    print("Dificultad: %s" % dificultad)
    mostrarMedidas(tiempos[dificultad-1])
# Out:
# RESULTADOS EN SEGUNDOS
# Dificultad: 1
# Count 	 100
# Min 	 0
# Max 	 58
# Med 	 1
# Avg 	 6.528717
# Std 	 8.982990
# Dificultad: 2
# Count 	 98
# Min 	 1
# Max 	 162
# Med 	 27
# Avg 	 44.801221
# Std 	 42.682321
# Dificultad: 3
# Count 	 98
# Min 	 0
# Max 	 171
# Med 	 25
# Avg 	 32.347886
# Std 	 30.477790
# Dificultad: 4
# Count 	 66
# Min 	 0
# Max 	 178
# Med 	 75
# Avg 	 79.766048
# Std 	 52.287284
# Dificultad: 5
# Count 	 77
# Min 	 0
# Max 	 172
# Med 	 51
# Avg 	 62.687496
# Std 	 49.142598
# Dificultad: 6
# Count 	 100
# Min 	 0
# Max 	 9
# Med 	 0
# Avg 	 1.785405
# Std 	 1.838617
# Dificultad: 7
# Count 	 97
# Min 	 0
# Max 	 173
# Med 	 28
# Avg 	 39.111002
# Std 	 37.717911
# Dificultad: 8
# Count 	 45
# Min 	 1
# Max 	 173
# Med 	 49
# Avg 	 72.790311
# Std 	 54.226438
# Dificultad: 9
# Count 	 41
# Min 	 1
# Max 	 179
# Med 	 75
# Avg 	 79.496225
# Std 	 56.149750

# %%
print("RESULTADOS EN CANTIDAD DE GENERACIONES")
for dificultad in range(1, 10):
    print("Dificultad: %s" % dificultad)
    mostrarMedidas(iters[dificultad-1])
# Out:
# RESULTADOS EN CANTIDAD DE GENERACIONES
# Dificultad: 1
# Count 	 100
# Min 	 15
# Max 	 1196
# Med 	 40
# Avg 	 139.130000
# Std 	 186.235746
# Dificultad: 2
# Count 	 98
# Min 	 33
# Max 	 4077
# Med 	 639
# Avg 	 1085.418367
# Std 	 1040.929480
# Dificultad: 3
# Count 	 98
# Min 	 24
# Max 	 4359
# Med 	 649
# Avg 	 839.918367
# Std 	 782.009547
# Dificultad: 4
# Count 	 66
# Min 	 23
# Max 	 4558
# Med 	 1908
# Avg 	 2045.212121
# Std 	 1336.009804
# Dificultad: 5
# Count 	 77
# Min 	 25
# Max 	 4454
# Med 	 1294
# Avg 	 1614.779221
# Std 	 1259.047874
# Dificultad: 6
# Count 	 100
# Min 	 12
# Max 	 201
# Med 	 25
# Avg 	 41.610000
# Std 	 38.952252
# Dificultad: 7
# Count 	 97
# Min 	 27
# Max 	 4601
# Med 	 781
# Avg 	 1028.783505
# Std 	 987.373713
# Dificultad: 8
# Count 	 45
# Min 	 35
# Max 	 5066
# Med 	 1467
# Avg 	 2130.466667
# Std 	 1583.778346
# Dificultad: 9
# Count 	 41
# Min 	 51
# Max 	 5278
# Med 	 2192
# Avg 	 2335.341463
# Std 	 1644.170272

# %%
print("RESULTADOS EN SEGUNDOS, SEGUNDO SET DE SUDOKUS")
for dificultad in range(10, 16):
    print("Dificultad: %s" % dificultad)
    mostrarMedidas(tiempos[dificultad-1])
# Out:
# RESULTADOS EN SEGUNDOS, SEGUNDO SET DE SUDOKUS
# Dificultad: 10
# Count 	 30
# Min 	 1
# Max 	 82
# Med 	 19
# Avg 	 24.861524
# Std 	 22.771488
# Dificultad: 11
# Count 	 29
# Min 	 1
# Max 	 358
# Med 	 65
# Avg 	 106.435882
# Std 	 102.269533
# Dificultad: 12
# Count 	 8
# Min 	 41
# Max 	 259
# Med 	 167
# Avg 	 153.818863
# Std 	 94.258201
# Dificultad: 13
# Count 	 30
# Min 	 0
# Max 	 25
# Med 	 3
# Avg 	 5.990669
# Std 	 6.307878
# Dificultad: 14
# Count 	 29
# Min 	 1
# Max 	 350
# Med 	 89
# Avg 	 98.794415
# Std 	 87.153259
# Dificultad: 15
# Count 	 30
# Min 	 4
# Max 	 239
# Med 	 47
# Avg 	 73.371898
# Std 	 61.037877

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 0 Completar tabla de resultados de la seccion 3.1.2 mirando el paper:
# http://sumitbhatia.net/papers/sudokuTechReport.pd

# %%
# 1
# Hacer grafico de barra
# Eje X : dificultades (de la 1 a la 9, poner los nombres de las dificultades como en la tabla)
# Eje y: tiempos PROMEDO Y MAXIMO (en segundos) (3 columnas por dificultad)
# El minimo lo sacamos porque es para todos igual

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 15}

plt.rc('font', **font)

plt.figure(figsize=(15,10))

maximos = []
promedios = []
for i in range(0, 9):
    maximos.append(np.max(tiempos[i]))
    promedios.append(np.mean(tiempos[i]))
datos = [promedios, maximos]

X = np.arange(9)
plt.bar(X + 0.25, datos[0], color = "r", width = 0.25)
plt.bar(X + 0.50, datos[1], color = "g", width = 0.25)
plt.xticks(X+0.38, ["1*","2*","3*","4*", "5*", "E" , "C", "D", "SD"])
plt.legend(['Promedio', 'Máximo'], bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
plt.yticks(np.arange(0, 180, 10))
plt.xlabel("Dificultad de sudoku")
plt.ylabel("Tiempo en segundos")
ax = plt.axes()        
ax.yaxis.grid(linestyle='dotted')
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /usr/local/lib/python3.6/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# 2
# Hacer grafico de iteraciones
# Igual al de la pagina 5 del paper https://pdfs.semanticscholar.org/1331/c019866526aad677279d1791a23805742ce7.pdf

plt.figure(figsize=(15,10))
plt.vlines(x=np.mean(iters[0]), ymin=min(iters[0]), ymax=max(iters[0]), colors="red", linewidth = 5, label="1*")
plt.vlines(x=np.mean(iters[1]), ymin=min(iters[1]), ymax=max(iters[1]), colors="green", linewidth = 5, label="2*")
plt.vlines(x=np.mean(iters[2]), ymin=min(iters[2]), ymax=max(iters[2]), colors="blue", linewidth = 5, label="3*")
plt.vlines(x=np.mean(iters[3]), ymin=min(iters[3]), ymax=max(iters[3]), colors="fuchsia", linewidth = 5, label="4*")
plt.vlines(x=np.mean(iters[4]), ymin=min(iters[4]), ymax=max(iters[4]), colors="black", linewidth = 5, label="5*")
plt.vlines(x=np.mean(iters[5]), ymin=min(iters[5]), ymax=max(iters[5]), colors="purple", linewidth = 5, label="Easy")
plt.vlines(x=np.mean(iters[6]), ymin=min(iters[6]), ymax=max(iters[6]), colors="yellow", linewidth = 5, label="Challenging")
plt.vlines(x=np.mean(iters[7]), ymin=min(iters[7]), ymax=max(iters[7]), colors="teal", linewidth = 5, label="Difficult")
plt.vlines(x=np.mean(iters[8]), ymin=min(iters[8]), ymax=max(iters[8]), colors="orange", linewidth = 5, label="Super Difficult")
plt.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)

plt.yticks(np.arange(0, 6000, 500))
ax = plt.axes()        
ax.yaxis.grid(linestyle='dotted')

plt.xlabel("Promedio de generaciones")
plt.ylabel("Cantidad de generacions (min y max)")
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /usr/local/lib/python3.6/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# 3
# Hacer tabla comparando con tabu search tiempos de los sudokus 10 al 15
# Copiar los valores de la pagina 4 de https://pdfs.semanticscholar.org/8614/d90f2989e13787da2361f700fd3889dd170a.pdf

# %%
# Optimizacion de parametros

import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate

x = [0.2, 0.4, 0.6, 0.8]
y = [120.41, 96.24, 75.11, 111.865]
tck = interpolate.splrep(x, y, s=0)
xnew = np.arange(0.2, 0.8, 0.01)
ynew = interpolate.splev(xnew, tck, der=0)
plt.figure(figsize=(10,6))
plt.plot(xnew, ynew)
plt.scatter(x,y)
plt.xlabel("Probabilidad de mutacion")
plt.ylabel("Tiempo promedio(s)")
plt.show()
